# %% [markdown]
# <a href="https://colab.research.google.com/github/VanNguyenThiCam/Frameworks/blob/main/Tensorflow_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![277186090_1413804342390644_2196027783012216329_n.jpg](data:image/jpeg;base64,...)

# %%
import tensorflow.keras as keras

model = keras.Sequential()
model.add(keras.Input(shape = (3,)))
model.add(keras.layers.Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 4
#
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Param: Tham số là 3 + 1 bias nên là 4

# %% [markdown]
# ![277419337_364081692285974_4087533999883104719_n.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras

model = keras.Sequential()
model.add(keras.Input(shape =(4,)))
model.add(keras.layers.Dense(units = 3))
model.add(keras.layers.Activation(keras.activations.softmax))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 3)                 15
#
#  activation (Activation)     (None, 3)                 0
#
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Chú thích**
#
#
#
# *   Trong 1 bài toán mình sẽ training với 3 dạng. 1 sample, m sample, N sample. Nên chữ None là sẽ cho mình biết mình sẽ training với bao nhiêu sample.
# *   Tham số là (4+1bias) * 3 = 15
